# %% [markdown]
# ## Exploratory Data Analysis and Preprocessing Insights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2

# %%
## Load metadata
df = pd.read_csv("../data/metadata - standardized.csv")
df.head()
# Out:
#                      names  types type_expanded  isColor   original_name  \
# 0  OIA-ODIR-TEST-OFFLINE-1      0           NaN        1  1029_right.jpg
# 1  OIA-ODIR-TEST-OFFLINE-2      0           NaN        1   1049_left.jpg
# 2  OIA-ODIR-TEST-OFFLINE-4      0           NaN        1   1128_left.jpg
# 3  OIA-ODIR-TEST-OFFLINE-5      0           NaN        1  1179_right.jpg
# 4  OIA-ODIR-TEST-OFFLINE-6      0           NaN        1   1180_left.jpg
#
#   patient_id                                    fundus fundus_od_seg  \
# 0        NaN  /full-fundus/OIA-ODIR-TEST-OFFLINE-1.png           NaN
# 1        NaN  /full-fundus/OIA-ODIR-TEST-OFFLINE-2.png           NaN
# 2        NaN  /full-fundus/OIA-ODIR-TEST-OFFLINE-4.png           NaN
# 3        NaN  /full-fundus/OIA-ODIR-TEST-OFFLINE-5.png           NaN
# 4        NaN  /full-fundus/OIA-ODIR-TEST-OFFLINE-6.png           NaN
#
#   fundus_oc_seg bv_seg  ... cdr_expert4 refractive_dioptre_1  \
# ...

# %% [markdown]
# | Column        | Meaning                   |
# | ------------- | ------------------------- |
# | fundus        | Path to fundus image      |
# | fundus_od_seg | Optic disc segmentation   |
# | fundus_oc_seg | Optic cup segmentation    |
# | bv_seg        | Blood vessel segmentation |
# | artery_seg    | Artery segmentation       |
# | vein_seg      | Vein segmentation         |
# | oct           | OCT image                 |
# | oct_oc_seg    | OCT cup segmentation      |
# | oct_od_seg    | OCT disc segmentation     |
#
# ### Dataset Overview – Analytical Remarks
#
# The dataset contains 12,316 total samples with 48 metadata features.
# Each sample corresponds to a retinal fundus image along with associated structured attributes.
#
# Key Observations:
# - Each sample has a valid fundus image path.
# - The `types` column represents diagnostic labels.
#
# This dataset is sufficiently large for deep learning, but medical imaging tasks require careful handling due to subtle pathological differences.

# %%
## dataset shape
print("Total samples:", len(df))
df.info()
# Out:
# Total samples: 12449
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   names                     12449 non-null  object
#  1   types                     12449 non-null  int64
#  2   type_expanded             6577 non-null   object
#  3   isColor                   12449 non-null  int64
#  4   original_name             12449 non-null  object
#  5   patient_id                488 non-null    object
#  6   fundus                    12449 non-null  object
#  7   fundus_od_seg             3103 non-null   object
#  8   fundus_oc_seg             3103 non-null   object
#  9   bv_seg                    462 non-null    object
#  10  artery_seg                22 non-null     object
#  11  vein_seg                  22 non-null     object
#  12  oct                       79 non-null     object
# ...

# %%
df['types'].unique()
# Out:
# array([ 0,  1, -1])

# %% [markdown]
# -1 → Suspected
#
# 0 → Normal
#
# 1 → Glaucoma

# %% [markdown]
# ### Cleaning the Dataset

# %%
## Removing class suspected to perform binary classification to avoid ambiguity.
df = df[df['types'] != -1]

# %% [markdown]
# ### Binary Classification Justification
#
# The "Suspected" class (-1) was removed to simplify the problem into a binary classification task (Normal vs Glaucoma).
#
# Reasoning:
# - Suspected cases may introduce label ambiguity.
# - Binary classification allows clearer decision boundaries.
# - For early experimentation, reducing class complexity improves interpretability.
#
# Future Scope:
# A multi-class classification approach (Normal vs Suspected vs Glaucoma) could be explored once baseline performance is established.

# %%
## Checking missing values
df.isnull().sum()
# Out:
# names                           0
# types                           0
# type_expanded                5807
# isColor                         0
# original_name                   0
# patient_id                  11896
# fundus                          0
# fundus_od_seg                9281
# fundus_oc_seg                9281
# bv_seg                      11854
# artery_seg                  12294
# vein_seg                    12294
# oct                         12237
# oct_oc_seg                  12271
# oct_od_seg                  12271
# sex                          7852
# gender                      11896
# age                          7432
# eye                          6703
# sbp                         12294
# dbp                         12294
# hr                          12294
# iop                         12294
# vcdr                        11666
# Unnamed: 24                 12316
# notchI_present              12215
# notchS_present              12215
# ...

# %% [markdown]
# ### Missing Value Analysis – Interpretation
#
# Core columns such as:
# - `names`
# - `types`
# - `fundus`
# - `original_name`
#
# contain zero missing values.
#
# Implications:
# - Every image has a corresponding label.
# - Dataset integrity is strong.
# - No imputation is required for classification.
#
# This reduces preprocessing complexity and ensures clean supervised learning.

# %% [markdown]
# ### Class Distribution Analysis

# %%
df['types'].value_counts()
# Out:
# types
# 0    7549
# 1    4767
# Name: count, dtype: int64

# %%
(df['types'].value_counts(normalize=True) * 100)
# Out:
# types
# 0    61.294251
# 1    38.705749
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='types', data=df)
plt.title("Class Distribution")
plt.xticks([0,1], ["Normal", "Glaucoma"])
plt.show()

# %%
sns.histplot(df['age'].dropna())
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# Glaucoma risk increases with age.

# %% [markdown]
# ### Class Imbalance Analysis
#
# The distribution of classes indicates an imbalance between Normal and Glaucoma samples.
#
# Implications:
# - Accuracy alone may not be a reliable metric.
# - The model may become biased toward the majority class.
# - Minority class (Glaucoma) detection is clinically critical.
#
# Medical Perspective:
# False Negatives (predicting Normal when Glaucoma is present) are more dangerous than False Positives.
# Missing glaucoma cases may lead to irreversible vision loss.
#
# Therefore:
# - Evaluation should prioritize Recall and F1-score.
# - Class balancing or augmentation may be required.

# %% [markdown]
# ### Image Path Construction

# %%
import os

print(os.listdir("../data/full-fundus/full-fundus")[:10])
# Out:
# ['EyePACS-Glaucoma-2520.png', 'EyePACS-Glaucoma-2659.png', 'OIA-ODIR-TEST-OFFLINE-423.png', 'REFUGE1-train-343.png', 'OIA-ODIR-TRAIN-2788.png', 'EyePACS-Glaucoma-107.png', 'OIA-ODIR-TRAIN-14.png', 'BEH-634.png', 'OIA-ODIR-TRAIN-2615.png', 'EyePACS-Glaucoma-1579.png']

# %%
BASE_DIR = "../data/full-fundus/full-fundus"

df['path'] = df['names'].apply(
    lambda x: os.path.join(BASE_DIR, x + ".png")
)

# %%
print(df["path"].iloc[0])
print(os.path.exists(df['path'].iloc[0]))
# Out:
# ../data/full-fundus/full-fundus/OIA-ODIR-TEST-OFFLINE-1.png
# True

# %% [markdown]
# ### Image Resolution Analysis

# %%
heights = []
widths = []

for path in df['path'].sample(500):
    img = cv2.imread(path)
    h, w, _ = img.shape
    heights.append(h)
    widths.append(w)

# %%
plt.hist(heights, bins=20)
plt.title("Image Height Distribution")
plt.show()

# %%
plt.hist(widths, bins=20)
plt.title("Image Width Distribution")
plt.show()

# %% [markdown]
# ### Image Height Analysis – Interpretation
#
# The histogram shows that all images have a height of 512 pixels.
#
# There is no variation in image height across the dataset.
#
# Implications:
# - The dataset is standardized in vertical resolution.
# - No resizing is required for height consistency.
# - This simplifies preprocessing.
#
# This indicates controlled image acquisition or prior preprocessing before dataset release.

# %% [markdown]
# ### Visual Inspection of Images

# %%
normal_imgs = df[df['types'] == 0]['path'].sample(6)

plt.figure(figsize=(12,6))
for i, path in enumerate(normal_imgs):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,i+1)
    plt.imshow(img)
    plt.axis("off")
plt.suptitle("Normal Fundus Images")
plt.show()

# %%
normal_imgs = df[df['types'] == 1]['path'].sample(6)

plt.figure(figsize=(12,6))
for i, path in enumerate(normal_imgs):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,i+1)
    plt.imshow(img)
    plt.axis("off")
plt.suptitle("Glaucoma Fundus Images")
plt.show()

# %% [markdown]
# ### Visual Differences Between Classes
#
# Upon visual inspection:
#
# Normal Images:
# - Smaller cup-to-disc ratio
# - Clear optic disc boundaries
# - Healthy neuroretinal rim
#
# Glaucoma Images:
# - Enlarged optic cup
# - Thinning of neuroretinal rim
# - Structural deformation around optic disc
#
# Important Insight:
# The differences are structural rather than color-based.
# Therefore, the model must learn morphological patterns rather than superficial pixel intensity differences.

# %% [markdown]
# ### Pixel Intensity Distribution

# %%
## flatten pixels
sample_img = cv2.imread(df['path'].iloc[0])
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)

plt.hist(sample_img.flatten(), bins=50)
plt.title("Pixel Intensity Distribution")
plt.show()

# %% [markdown]
# ### Pixel Intensity Analysis – Interpretation
#
# The histogram shows pixel values distributed between 0 and 255.
#
# Observations:
# - Intensity distribution is non-uniform.
# - Fundus images contain large dark background regions.
# - Bright optic disc areas create peaks in higher intensities.
#
# Preprocessing Decision:
# - Normalize pixel values to range [0, 1].
# - This improves gradient stability during training.
#
# Medical Relevance:
# Subtle contrast variations around the optic disc are critical for glaucoma detection.
# Normalization ensures consistent intensity scaling across samples.

# %%
plt.hist(img[:,:,0].flatten(), alpha=0.5, label='R')
plt.hist(img[:,:,1].flatten(), alpha=0.5, label='G')
plt.hist(img[:,:,2].flatten(), alpha=0.5, label='B')
# Out:
# (array([72915.,  1983., 38697., 73033., 34037., 20095., 10956.,  6176.,
#          3275.,   977.]),
#  array([0.        , 0.05960784, 0.11921569, 0.17882353, 0.23843137,
#         0.29803922, 0.35764706, 0.4172549 , 0.47686275, 0.53647059,
#         0.59607843]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Train / Val / Test Split Analysis

# %%
image_directory = r'..\data\full-fundus\full-fundus'
image_size = 256
seed = 24
batch_size = 32

def get_path(name):
    return image_directory + '\\' + name + '.png'

df['path'] = df['names'].apply(get_path)
df.drop('names', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
train_data, val_data = train_test_split(df, test_size=0.2, random_state=seed)
train_data, test_data = train_test_split(train_data, test_size=0.1, random_state=seed)

# %%
print("Train:", train_data['types'].value_counts())
print("Val:", val_data['types'].value_counts())
print("Test:", test_data['types'].value_counts())
# Out:
# Train: types
# 0    5433
# 1    3433
# Name: count, dtype: int64
# Val: types
# 0    1527
# 1     937
# Name: count, dtype: int64
# Test: types
# 0    589
# 1    397
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1,3, figsize=(15,4))

sns.countplot(x='types', data=train_data, ax=axes[0])
axes[0].set_title("Train")

sns.countplot(x='types', data=val_data, ax=axes[1])
axes[1].set_title("Validation")

sns.countplot(x='types', data=test_data, ax=axes[2])
axes[2].set_title("Test")

plt.show()

# %% [markdown]
# ### Data Augmentation Visualization

# %%
print(train_data['path'].iloc[0])
# Out:
# ..\data\full-fundus\full-fundus\OIA-ODIR-TEST-ONLINE-263.png

# %% [markdown]
# ### Data Augmentation – Motivation
#
# Medical datasets are typically limited and imbalanced.
#
# Data augmentation helps:
# - Increase effective dataset size
# - Improve generalization
# - Reduce overfitting
# - Improve minority class representation
#
# However, transformations must preserve anatomical integrity.
# Extreme distortions are avoided to maintain clinical validity.
# In our case, Data augmentation is applied only to the training set to improve generalization.
# Validation and test sets remain untouched to ensure unbiased evaluation.
#
# Augmentation simulates real-world variability such as slight head tilt and camera shifts,
# while preserving anatomical structure.
