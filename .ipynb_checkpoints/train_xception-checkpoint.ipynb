# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2026-03-30 11:21:00.616381: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-30 11:21:00.616433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-30 11:21:00.618049: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-30 11:21:00.630482: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.15.0

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, precision_recall_fscore_support
import tensorflow as tf 
import tensorflow_addons as tfa
import wandb
import json
from wandb.integration.keras import WandbMetricsLogger
from models import Xception, ResNet50
sns.set_style("darkgrid")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# /home/jupyter-st126490-ml/.conda/envs/smdg_gpu/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
df = pd.read_csv('../data/metadata - standardized.csv')
df = pd.DataFrame(df[['names','types']])

# %%
print(df.columns)
# Out:
# Index(['names', 'types'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   12449 non-null  object
#  1   types   12449 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 194.6+ KB

# %%
df.isnull().sum()
# Out:
# names    0
# types    0
# dtype: int64

# %%
df = df[df['types'] != -1]

# %%
df['types'].value_counts()
# Out:
# types
# 0    7549
# 1    4767
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=df['types'])
plt.title("Class Distribution")
plt.show()

# %%
image_directory = r'..\data\full-fundus\full-fundus'
image_size = 256
seed = 24
batch_size = 32

def get_path(name):
    return image_directory + '\\' + name + '.png'

df['path'] = df['names'].apply(get_path)
df.drop('names', axis=1, inplace=True)

# %%
train_data, val_data = train_test_split(df, test_size=0.2, random_state=seed)
train_data, test_data = train_test_split(train_data, test_size=0.1, random_state=seed)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8866 entries, 715 to 1024
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   types   8866 non-null   int64
#  1   path    8866 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 207.8+ KB

# %%
import os

BASE_DIR = "../data/full-fundus/full-fundus"

def fix_path(p):
    # Replace Windows slashes
    p = p.replace("\\", "/")
    
    # Remove everything before last occurrence of full-fundus
    filename = p.split("full-fundus/")[-1]
    
    # Build correct absolute path
    return os.path.join(BASE_DIR, filename)

train_data["path"] = train_data["path"].apply(fix_path)
val_data["path"] = val_data["path"].apply(fix_path)
test_data["path"] = test_data["path"].apply(fix_path)

# %%
print(train_data["path"].iloc[0])
print(os.path.exists(train_data["path"].iloc[0]))
# Out:
# ../data/full-fundus/full-fundus/OIA-ODIR-TEST-ONLINE-263.png
# True

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2464 entries, 7492 to 1896
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   types   2464 non-null   int64
#  1   path    2464 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 57.8+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 986 entries, 3280 to 8590
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   types   986 non-null    int64
#  1   path    986 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 23.1+ KB

# %%
class ImageGenerator(tf.keras.utils.Sequence):
    """
    Custom Image data generator class from Image paths and labels
    """
    def __init__(self, data: pd.DataFrame, batch_size: int=batch_size, image_size: tuple=image_size, balance: bool=False, augment: bool=False):
        if balance:
            self.data = self.__balance__(data)
        else:
            self.data = data
        self.labels = self.data['types'].values
        self.image_path = self.data['path'].values
        self.batch_size = batch_size
        self.image_size = (image_size, image_size)
        self.augment = augment
        self.augment_pipe = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
            tf.keras.layers.experimental.preprocessing.RandomZoom(0.3),
            tf.keras.layers.experimental.preprocessing.RandomContrast(0.2),
            tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
            tf.keras.layers.experimental.preprocessing.RandomTranslation(0.2, 0.2)
        ])
    
    def __augment__(self, image):
        if np.random.rand() > 0.7:
            image = self.augment_pipe(image)
        return image

    def __balance__(self, data):
        data_pos, data_neg = data[data['types'] == 1], data[data['types'] == 0]
        data_neg = data_neg.sample(len(data_pos), replace=False, random_state=seed)
        data = pd.concat([data_pos, data_neg])
        data = data.sample(frac=1)
        return data
    
    def __len__(self):
        return np.math.ceil(len(self.image_path) / self.batch_size)

    def __get_image__(self, image_path):
        image = tf.keras.preprocessing.image.load_img(image_path, target_size=self.image_size)
        image = tf.keras.preprocessing.image.img_to_array(image)
        return image
    
    def __getitem__(self, index):

        batch_images = self.image_path[index * self.batch_size : (index + 1) * self.batch_size]
        batch_images = np.array([self.__augment__(self.__get_image__(path)) for path in batch_images]) / 255.0
        batch_labels = self.labels[index * self.batch_size : (index + 1) * self.batch_size]
        return batch_images, batch_labels

# %%
train_dataset = ImageGenerator(train_data, balance=True, augment=True)
val_dataset = ImageGenerator(val_data, balance=False, augment=False)
test_dataset = ImageGenerator(test_data, balance=False, augment=False)
# Out:
# 2026-03-30 11:21:06.691143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9796 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:84:00.0, compute capability: 7.5
# 2026-03-30 11:21:06.692063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9796 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:85:00.0, compute capability: 7.5
# 2026-03-30 11:21:06.692822: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9796 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2026-03-30 11:21:06.693570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9796 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5

# %%
print(train_data['path'].head())
# Out:
# 715      ../data/full-fundus/full-fundus/OIA-ODIR-TEST-...
# 9337     ../data/full-fundus/full-fundus/EyePACS-Glauco...
# 6071           ../data/full-fundus/full-fundus/BEH-475.png
# 11662       ../data/full-fundus/full-fundus/PAPILA-102.png
# 403      ../data/full-fundus/full-fundus/OIA-ODIR-TEST-...
# Name: path, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
im,l = train_dataset.__getitem__(np.random.randint(0, len(train_dataset)))
for i in range(9):
  ax = plt.subplot(3, 3, i+1)
  plt.imshow(im[i])
  plt.title(l[i])
  plt.axis("off")
# Out:
# /tmp/ipykernel_1293209/2614793993.py:36: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.math.ceil(len(self.image_path) / self.batch_size)

# %% [markdown]
# ## Xception Model

# %% [markdown]
# ### Initializing

# %% [markdown]
# #### Hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
beta_1 = 0.9
num_epochs = 20
checkpoint_filepath_xcp = r'saved_model\xception\weights.h5'

# %% [markdown]
# #### Wandb

# %%
wandb.init(
    id = "0x001",
    project="Explainable Deep Learning for Glaucoma Detection",
    name = 'Xception',

    # track hyperparameters and run metadata
    config={
        "Dataset": "Glaucoma",
        "Models": "Xception",
        "learning_rate": learning_rate,
        "beta1": beta_1,
        "metrics": ["accuracy"],
    }
)
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/jupyter-st126490-ml/.netrc.
# wandb: Currently logged in as: st126490 (st126490-asian-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/jupyter-st126490-ml/p1/SMDG-Classifier/SMDG-Classifier/wandb/run-20260330_112110-0x001</code>
# Syncing run <strong><a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001' target="_blank">Xception</a></strong> to <a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection' target="_blank">https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection</a>
#  View run at <a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001' target="_blank">https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# #### Trainer

# %%
def run_training(model, load_checkpoint=True):
    optimizer = optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, 
        weight_decay=weight_decay,
        beta_1=beta_1
        
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
        metrics=[
           'accuracy',
        ],
    )

    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath_xcp,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
    )

    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
    )


    if load_checkpoint:
        model.load_weights(checkpoint_filepath_xcp)

    history = model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=val_dataset,
        callbacks=[checkpoint_callback,
                   WandbMetricsLogger(log_freq='batch'),
                   early_stopping_callback
                   ],
    )
    model_path = f"saved_model/xception_tf"
    model.save(model_path, save_format="tf")

    print(f"Full model saved at saved_model/xception_full.keras")
    
    metadata = {
        "model_name": "xception",
        "input_size": [224, 224],
        "classes": ["Normal", "Glaucoma"],
        "threshold": 0.5
    }

    metadata_path = f"saved_model/xception_config.json"

    with open(metadata_path, "w") as f:
        json.dump(metadata, f, indent=4)

    print(f" Model saved at: {model_path}")
    print(f" Metadata saved at: {metadata_path}")
    return history

# %% [markdown]
# #### Evaluator

# %%
def run_evalutation(model, dataset):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, 
        weight_decay=weight_decay,
        beta_1=beta_1
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
        metrics=[
           'accuracy',
        ],
    )
    model.load_weights(checkpoint_filepath_xcp)
    _, accuracy = model.evaluate(dataset)
    predictions = model.predict(dataset)
    predictions = tf.where(predictions < 0.5, 0, 1)
    report = classification_report(dataset.labels, predictions)
    return accuracy, report

# %% [markdown]
# ### Building The Model

# %%
tf.keras.backend.clear_session()
xcp_classifier = Xception(input_shape=(image_size, image_size, 3), num_classes=1).build_model()

# %% [markdown]
# ### Training

# %%
history = run_training(xcp_classifier, load_checkpoint=False)
# Out:
# /tmp/ipykernel_1293209/2614793993.py:36: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.math.ceil(len(self.image_path) / self.batch_size)
# Epoch 1/20
# 2026-03-30 11:21:20.768970: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 215/215 [==============================] - 268s 1s/step - loss: 0.4552 - accuracy: 0.7911 - val_loss: 0.3969 - val_accuracy: 0.8072
# Epoch 2/20
# 215/215 [==============================] - 260s 1s/step - loss: 0.3502 - accuracy: 0.8474 - val_loss: 1.1119 - val_accuracy: 0.7005
# Epoch 3/20
# 215/215 [==============================] - 260s 1s/step - loss: 0.3197 - accuracy: 0.8586 - val_loss: 0.5113 - val_accuracy: 0.8011
# Epoch 4/20
# 215/215 [==============================] - 262s 1s/step - loss: 0.3008 - accuracy: 0.8689 - val_loss: 0.3633 - val_accuracy: 0.8555
# Epoch 5/20
# 215/215 [==============================] - 249s 1s/step - loss: 0.2689 - accuracy: 0.8800 - val_loss: 0.3563 - val_accuracy: 0.8531
# Epoch 6/20
# 215/215 [==============================] - 260s 1s/step - loss: 0.2529 - accuracy: 0.8905 - val_loss: 0.4405 - val_accuracy: 0.7914
# Epoch 7/20
# 215/215 [==============================] - 255s 1s/step - loss: 0.2396 - accuracy: 0.8956 - val_loss: 0.3424 - val_accuracy: 0.8547
# Epoch 8/20
# 215/215 [==============================] - 254s 1s/step - loss: 0.2245 - accuracy: 0.9018 - val_loss: 0.5143 - val_accuracy: 0.7934
# Epoch 9/20
# 215/215 [==============================] - 251s 1s/step - loss: 0.2081 - accuracy: 0.9101 - val_loss: 0.3793 - val_accuracy: 0.8417
# Epoch 10/20
# 215/215 [==============================] - 252s 1s/step - loss: 0.1988 - accuracy: 0.9126 - val_loss: 0.3733 - val_accuracy: 0.8490
# Epoch 11/20
# 215/215 [==============================] - 254s 1s/step - loss: 0.1852 - accuracy: 0.9208 - val_loss: 0.4180 - val_accuracy: 0.8458
# Epoch 12/20
# 215/215 [==============================] - 247s 1s/step - loss: 0.1836 - accuracy: 0.9237 - val_loss: 0.3589 - val_accuracy: 0.8511
# Full model saved at saved_model/xception_full.keras
#  Model saved at: saved_model/xception_full.keras
#  Metadata saved at: saved_model/xception_config.json

# %% [markdown]
# ### Evaluation

# %%
accuracy, report = run_evalutation(xcp_classifier, test_dataset)
pred_label = xcp_classifier.predict(test_dataset) > 0.5
precision,recall,f1_score,_ =  precision_recall_fscore_support(test_dataset.labels, pred_label, average='macro')
cm = confusion_matrix(test_dataset.labels, pred_label)
print("Accuracy on test dataset: ", accuracy)
print("Classification report:\n", report)
print("Confusion matrix:\n")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Glaucoma', 'Normal'])
disp.plot()
# Out:
# /tmp/ipykernel_1293209/2614793993.py:36: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.math.ceil(len(self.image_path) / self.batch_size)
# 31/31 [==============================] - 26s 800ms/step - loss: 0.3564 - accuracy: 0.8458
# 31/31 [==============================] - 24s 766ms/step
# /tmp/ipykernel_1293209/2614793993.py:36: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.math.ceil(len(self.image_path) / self.batch_size)
# 31/31 [==============================] - 24s 792ms/step
# Accuracy on test dataset:  0.8458417654037476
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       589
#            1       0.85      0.76      0.81       397
#
#     accuracy                           0.85       986
#    macro avg       0.85      0.84      0.84       986
# weighted avg       0.85      0.85      0.85       986
#
# Confusion matrix:

# %% [markdown]
# ### Generating the Heatmap

# %%
from cam import GRADgen
xcp_classifier.load_weights(checkpoint_filepath_xcp)
for i in range(3):
    random_batch = np.random.randint(0, 10)
    random_index = np.random.randint(0, 32)
    output, image, preds = GRADgen(xcp_classifier, 'block14_sepconv2_act', test_dataset.__getitem__(random_batch)[0][random_index])
    print(f"Predicted label: {preds} \nActual label: {test_dataset.__getitem__(random_batch)[1][random_index]}")
    fig = plt.figure(figsize=(15, 15))
    plt.subplot(3, 2, 2*i+1)
    plt.imshow(image)
    plt.axis('off')
    plt.subplot(3, 2, 2*i+2)
    plt.imshow(output)
    plt.axis('off')
    plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted label: [[1.]]
# Actual label: 1
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: [[1.]]
# Actual label: 0
# 1/1 [==============================] - 0s 28ms/step
# Predicted label: [[0.]]
# Actual label: 0

# %%
wandb.finish()
# Out:
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>▁▁▁▂▅▅▅▄▄▅▅▅▅▅▅▅▇▆▆▆▆▆▇▆▆▇▇▇▇▇▇▇▆▇▇▇██▇█</td></tr><tr><td>batch/batch_step</td><td>▁▁▁▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>batch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>█▆▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▃▃▃▃▁▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁</td></tr><tr><td>epoch/accuracy</td><td>▁▄▅▅▆▆▇▇▇▇██</td></tr><tr><td>epoch/epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▅▄▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▆▁▆██▅█▅▇███</td></tr><tr><td>epoch/val_loss</td><td>▁█▃▁▁▂▁▃▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>0.92368</td></tr><tr><td>batch/batch_step</td><td>2579</td></tr><tr><td>batch/learning_rate</td><td>0.001</td></tr><tr><td>batch/loss</td><td>0.18356</td></tr><tr><td>epoch/accuracy</td><td>0.92368</td></tr><tr><td>epoch/epoch</td><td>11</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.18356</td></tr><tr><td>epoch/val_accuracy</td><td>0.85106</td></tr><tr><td>epoch/val_loss</td><td>0.35892</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Xception</strong> at: <a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001' target="_blank">https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection/runs/0x001</a><br> View project at: <a href='https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection' target="_blank">https://wandb.ai/st126490-asian-institute-of-technology/Explainable%20Deep%20Learning%20for%20Glaucoma%20Detection</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260330_112110-0x001/logs</code>

# %%
# import tensorflow as tf
# def build_resnet():
#     base = tf.keras.applications.ResNet50(
#         weights=None,
#         include_top=False,
#         input_shape=(224,224,3)
#     )

#     x = base.output
#     x = tf.keras.layers.GlobalAveragePooling2D()(x)
#     x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

#     model = tf.keras.models.Model(inputs=base.input, outputs=x)
#     return model
# model = build_resnet()

# model.load_weights("saved_model/resnet/weights.h5")
# model.save("saved_model/resnet_tf", save_format="tf")
# import json

# metadata = {
#     "model_name": "resnet",
#     "input_size": [224, 224],
#     "classes": ["Normal", "Glaucoma"],
#     "threshold": 0.5
# }

# with open("saved_model/resnet_config.json", "w") as f:
#     json.dump(metadata, f, indent=4)
# Out:
# 2026-03-31 03:10:14.238647: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-31 03:10:14.238697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-31 03:10:14.239928: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-31 03:10:14.247967: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-31 03:10:17.855681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9796 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:84:00.0, compute capability: 7.5
# 2026-03-31 03:10:17.856628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9796 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:85:00.0, compute capability: 7.5
# 2026-03-31 03:10:17.857362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9796 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2026-03-31 03:10:17.858101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9796 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/resnet_tf/assets
# INFO:tensorflow:Assets written to: saved_model/resnet_tf/assets

# %%
# import tensorflow as tf

# def build_xception():
#     base = tf.keras.applications.Xception(
#         weights=None,                 # IMPORTANT
#         include_top=False,
#         input_shape=(224, 224, 3)
#     )

#     x = base.output
#     x = tf.keras.layers.GlobalAveragePooling2D()(x)
#     x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

#     model = tf.keras.models.Model(inputs=base.input, outputs=x)
#     return model
# model = build_xception()

# model.load_weights("saved_model/xception/weights.h5")
# model.save("saved_model/xception_tf", save_format="tf")
# import json

# metadata = {
#     "model_name": "xception",
#     "input_size": [224, 224],
#     "classes": ["Normal", "Glaucoma"],
#     "threshold": 0.5
# }

# with open("saved_model/xception_config.json", "w") as f:
#     json.dump(metadata, f, indent=4)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/xception_tf/assets
# INFO:tensorflow:Assets written to: saved_model/xception_tf/assets
